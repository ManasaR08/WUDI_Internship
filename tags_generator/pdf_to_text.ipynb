# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (1.26.0)

# %%
import PyPDF2
pdf = open('sample.pdf', 'rb')
pdfReader = PyPDF2.PdfFileReader(pdf)
print(pdfReader.numPages)
pageObj = pdfReader.getPage(1)
print(pageObj.extractText()) 
pdf.close()
# Out:
# 12
# (a)Kickoff
# (b)Yellowcard
# (c)Cornerkick
# Figure2:The
# FootballEngine
# isanadvancedfootballsimulatorthatsupportsallthemajorfootballrulessuchas(a)kickoffs
# (b)goals,fouls,cards,(c)cornerkicks,penaltykicks,andoffside.
# Contributions
# Inthispaper,weproposethe
# GoogleRe-
# searchFootballEnvironment
# ,anovelopen-sourcereinforce-
# mentlearningenvironmentwhereagentslearntoplayone
# oftheworld'smostpopularsports:football(a.k.a.soccer).
# Modeledafterpopularfootballvideogames,theFootball
# Environmentprovidesaphysics-based3Dfootballsimula-
# tionwhereagentshavetocontroltheirplayers,learnhowto
# passinbetweenthemandhowtoovercometheiropponent's
# defenseinordertoscoregoals.Thisprovidesachalleng-
# ingRLproblemasfootballrequiresanaturalbalancebe-
# tweenshort-termcontrol,learnedconceptssuchaspassing,
# andhighlevelstrategy.Asourkeycontributions,we
#
# providethe
# FootballEngine
# ,ahighly-optimizedgameen-
# ginethatsimulatesthegameoffootball,
#
# proposethe
# FootballBenchmarks
# ,aversatilesetofbench-
# marktasksofvaryingdifthatcanbeusedtocom-
# paredifferentalgorithms,
#
# proposethe
# FootballAcademy
# ,asetofprogressively
# harderanddiversereinforcementlearningscenarios,
#
# evaluatestate-of-the-artalgorithmsonboththe
# Football
# Benchmarks
# andthe
# FootballAcademy
# ,providinganex-
# tensivesetofreferenceresultsforfuturecomparison,
#
# provideasimpleAPItocompletelycustomizeand
# newfootballreinforcementlearningscenarios,and
#
# showcaseseveralpromisingresearchdirectionsinthisen-
# vironment,
# e.g.
# themulti-playerandmulti-agentsettings.
# MotivationandOtherRelatedWork
# Thereareavarietyofreinforcementlearningenvironments
# thathaveacceleratedresearchinrecentyears.However,ex-
# istingenvironmentsexhibitavarietyofdrawbacksthatwe
# addresswiththe
# GoogleResearchFootballEnvironment
# :
# Easytosolve.
# WiththerecentprogressinRL,manycom-
# monlyusedscenarioscannowbesolvedtoareasonablede-
# greeinjustafewhourswithwell-establishedalgorithms.
# Forinstance,
# ˘
# 50
# commonlyusedAtarigamesinthe
# Ar-
# cadeLearningEnvironment
# (Bellemareetal.,2013)arerou-
# tinelysolvedtosuper-humanlevel(Hesseletal.,2018).The
# sameappliestothe
# DeepMindLab
# (Beattieetal.,2016),a
# navigation-focusedmazeenvironmentthatprovidesanum-
# berofrelativelysimpletaskswithapersonviewpoint.
# Computationallyexpensive.
# Ontheotherhand,training
# agentsinrecentvideo-gamesimulatorsoftenrequiressub-
# stantialcomputationalresourcesthatmaynotbeavailableto
# alargefractionofresearchersduetocombininghardgames,
# longepisodes,andhigh-dimensionalinputs(eitherinthe
# formofpixels,orhand-craftedrepresentations).Forexam-
# ple,the
# StarCraftIILearningEnvironment
# (Vinyalsetal.,
# 2017)providesanAPIto
# StarcraftII
# ,awell-knownreal-
# timestrategyvideogame,aswellastoafewmini-games
# whicharecenteredaroundtasksinthegame.
# Lackofstochasticity.
# Thereal-worldisnotdeterministic
# whichmotivatestheneedtodevelopalgorithmsthatcan
# copewithandlearnfromstochasticenvironments.Robots,
# self-drivingcars,ordata-centersrequirerobustpolicies
# thataccountforuncertaindynamics.Yet,someofthemost
# popularsimulatedenvironmentsŒliketheArcadeLearning
# EnvironmentŒaredeterministic.Whiletechniqueshave
# beendevelopedtoaddrandomnesstotheenvi-
# ronment(likeskippingarandomnumberofinitialframes
# orusingstickyactions),thisrandomnessmaystillbetoo
# structuredandeasytopredictandincorporateduringtrain-
# ing(Machadoetal.,2018;HausknechtandStone,2015).It
# remainsanopenquestionwhethermodernRLapproaches
# suchasself-imitationgeneralizefromthedeterministic
# settingtostochasticenvironments(Guoetal.,2018).
# Lackofopen-sourcelicense.
# Someadvancedphysics
# simulatorsofferlicensesthatmaybesubjectedtorestric-
# tiveuseterms(Todorov,Erez,andTassa,2012).Also,some
# environmentssuchasStarCraftrequireaccesstoaclosed-
# sourcebinary.Incontrast,open-sourcelicensesenablere-
# searcherstoinspecttheunderlyinggamecodeandtomodify
# environmentsifrequiredtotestnewresearchideas.
# Knownmodeloftheenvironment.
# Reinforcementlearn-
# ingalgorithmshavebeensuccessfullyappliedtoboard
# gamessuchasBackgammon(Tesauro,1995),Chess(Hsu,
# 2004),orGo(Silveretal.,2016).Yet,currentstate-of-the-
# artalgorithmsoftenexploitthattherulesofthesegames
# (
# i.e.
# ,themodeloftheenvironment)areknownand
# canbeencodedintotheapproach.Assuch,thismaymake
# ithardtoinvestigatelearningalgorithmsthatshouldworkin
# environmentsthatcanonlybeexploredthroughinteractions.

# %%
import textract
text = textract.process("sample.pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\utils.py in run(self, args)
#      83                 args,
# ---> 84                 stdout=subprocess.PIPE, stderr=subprocess.PIPE,
#      85             )
#
# c:\users\user\appdata\local\programs\python\python36\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# c:\users\user\appdata\local\programs\python\python36\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1016                                          os.fspath(cwd) if cwd is not None else None,
# -> 1017                                          startupinfo)
#    1018             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ShellError                                Traceback (most recent call last)
# <ipython-input-7-94480cb1a56c> in <module>
#       1 import textract
# ----> 2 text = textract.process("sample.pdf")
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\__init__.py in process(filename, encoding, extension, **kwargs)
#      75
#      76     parser = filetype_module.Parser()
# ---> 77     return parser.process(filename, encoding, **kwargs)
#      78
#      79
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\utils.py in process(self, filename, encoding, **kwargs)
#      44         # output encoding
#      45         # http://nedbatchelder.com/text/unipain/unipain.html#35
# ---> 46         byte_string = self.extract(filename, **kwargs)
#      47         unicode_string = self.decode(byte_string)
#      48         return self.encode(unicode_string, encoding)
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\pdf_parser.py in extract(self, filename, method, **kwargs)
#      26                     return self.extract_pdfminer(filename, **kwargs)
#      27                 else:
# ---> 28                     raise ex
#      29
#      30         elif method == 'pdfminer':
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\pdf_parser.py in extract(self, filename, method, **kwargs)
#      18         if method == '' or method == 'pdftotext':
#      19             try:
# ---> 20                 return self.extract_pdftotext(filename, **kwargs)
#      21             except ShellError as ex:
#      22                 # If pdftotext isn't installed and the pdftotext method
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\pdf_parser.py in extract_pdftotext(self, filename, **kwargs)
#      41         else:
#      42             args = ['pdftotext', filename, '-']
# ---> 43         stdout, _ = self.run(args)
#      44         return stdout
#      45
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\textract\parsers\utils.py in run(self, args)
#      89                 # This is equivalent to getting exitcode 127 from sh
#      90                 raise exceptions.ShellError(
# ---> 91                     ' '.join(args), 127, '', '',
#      92                 )
#      93
#
# ShellError: The command `pdftotext sample.pdf -` failed with exit code 127
# ------------- stdout -------------
# ------------- stderr -------------

# %%
# !pip install textract
# Out:
# Collecting textract
#   Downloading textract-1.6.3-py3-none-any.whl (21 kB)
# Collecting argcomplete==1.10.0
#   Downloading argcomplete-1.10.0-py2.py3-none-any.whl (31 kB)
# Collecting EbookLib==0.17.1
#   Downloading EbookLib-0.17.1.tar.gz (111 kB)
# Collecting docx2txt==0.8
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
# Collecting beautifulsoup4==4.8.0
#   Downloading beautifulsoup4-4.8.0-py3-none-any.whl (97 kB)
# Collecting extract-msg==0.23.1
#   Downloading extract_msg-0.23.1-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: six==1.12.0 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from textract) (1.12.0)
# Requirement already satisfied: SpeechRecognition==3.8.1 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from textract) (3.8.1)
# Requirement already satisfied: xlrd==1.2.0 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from textract) (1.2.0)
# Requirement already satisfied: python-pptx==0.6.18 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from textract) (0.6.18)
# Requirement already satisfied: chardet==3.0.4 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from textract) (3.0.4)
# Collecting pdfminer.six==20181108
#   Downloading pdfminer.six-20181108-py2.py3-none-any.whl (5.6 MB)
# Requirement already satisfied: lxml in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from EbookLib==0.17.1->textract) (4.5.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from beautifulsoup4==4.8.0->textract) (2.0)
# Collecting imapclient==2.1.0
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
# Collecting tzlocal==1.5.1
#   Downloading tzlocal-1.5.1.tar.gz (16 kB)
# Collecting olefile==0.46
#   Downloading olefile-0.46.zip (112 kB)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from python-pptx==0.6.18->textract) (6.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from python-pptx==0.6.18->textract) (1.2.9)
# Collecting sortedcontainers
#   Downloading sortedcontainers-2.3.0-py2.py3-none-any.whl (29 kB)
# Collecting pycryptodome
#   Downloading pycryptodome-3.9.9-cp36-cp36m-win_amd64.whl (14.1 MB)
# Requirement already satisfied: pytz in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract) (2019.3)
# Building wheels for collected packages: EbookLib, docx2txt, tzlocal, olefile
#   Building wheel for EbookLib (setup.py): started
#   Building wheel for EbookLib (setup.py): finished with status 'done'
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-py3-none-any.whl size=38169 sha256=23f182c7f5572e1d545805e2f892007bf07230b58f7a9aa149b1caa35668c6ef
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\b4\83\65\67f90f3f9cdd3eb5330e495fbbd488bc3c0854f76eed1b704c
#   Building wheel for docx2txt (setup.py): started
#   Building wheel for docx2txt (setup.py): finished with status 'done'
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3969 sha256=09883dd35fef9e9aec062600dac4d996bf4d93733da25d5534e71b3423efbebd
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\66\d7\77\4dc0e151e2ef19b5474722fd943e312603f10016baab494f7a
#   Building wheel for tzlocal (setup.py): started
#   Building wheel for tzlocal (setup.py): finished with status 'done'
#   Created wheel for tzlocal: filename=tzlocal-1.5.1-py3-none-any.whl size=17550 sha256=af40422167023586b54399b4847854deef980f403df586ecdc2a9ac41d2119b5
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\9b\ea\ca\a3c0116bd004529390dc7bcb5d7f8de1bf985e01738cc9a11c
#   Building wheel for olefile (setup.py): started
#   Building wheel for olefile (setup.py): finished with status 'done'
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35421 sha256=8f6f2fc82f408505da54e9a0c1159db947e8b3c1f107f14ae655ab9502ded8da
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\bc\9d\f9\4f5e50f497a2ed398d9786244df90cee57583e92bff76bfc2b
# Successfully built EbookLib docx2txt tzlocal olefile
# Installing collected packages: argcomplete, EbookLib, docx2txt, beautifulsoup4, imapclient, tzlocal, olefile, extract-msg, sortedcontainers, pycryptodome, pdfminer.six, textract
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.8.2
#     Uninstalling beautifulsoup4-4.8.2:
#       Successfully uninstalled beautifulsoup4-4.8.2
# Successfully installed EbookLib-0.17.1 argcomplete-1.10.0 beautifulsoup4-4.8.0 docx2txt-0.8 extract-msg-0.23.1 imapclient-2.1.0 olefile-0.46 pdfminer.six-20181108 pycryptodome-3.9.9 sortedcontainers-2.3.0 textract-1.6.3 tzlocal-1.5.1

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.5.24.tar.gz (42 kB)
# Collecting pdfminer.six==20200517
#   Downloading pdfminer.six-20200517-py3-none-any.whl (5.6 MB)
# Collecting Pillow>=7.0.0
#   Using cached Pillow-8.0.1-cp36-cp36m-win_amd64.whl (2.1 MB)
# Collecting Wand
#   Downloading Wand-0.6.4-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied: sortedcontainers in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from pdfminer.six==20200517->pdfplumber) (2.3.0)
# Requirement already satisfied: chardet; python_version > "3.0" in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from pdfminer.six==20200517->pdfplumber) (3.0.4)
# Requirement already satisfied: pycryptodome in c:\users\user\appdata\local\programs\python\python36\lib\site-packages (from pdfminer.six==20200517->pdfplumber) (3.9.9)
# Building wheels for collected packages: pdfplumber
#   Building wheel for pdfplumber (setup.py): started
#   Building wheel for pdfplumber (setup.py): finished with status 'done'
#   Created wheel for pdfplumber: filename=pdfplumber-0.5.24-py3-none-any.whl size=31146 sha256=3e3c0931e6f0709dcf5d5a38ec3ea93efde157af8c9e26fbb9607cd474ec3616
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\77\3d\22\f553e874db23b5269561cdbf6e151ab52f2211971539f80292
# Successfully built pdfplumber
# Installing collected packages: pdfminer.six, Pillow, Wand, pdfplumber
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20181108
#     Uninstalling pdfminer.six-20181108:
#       Successfully uninstalled pdfminer.six-20181108
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 6.2.1
#     Uninstalling pillow-6.2.1:
#       Successfully uninstalled pillow-6.2.1
# Successfully installed Pillow-8.0.1 Wand-0.6.4 pdfminer.six-20200517 pdfplumber-0.5.24
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# textract 1.6.3 requires pdfminer.six==20181108, but you'll have pdfminer-six 20200517 which is incompatible.

# %%
import pdfplumber

with pdfplumber.open(r.pdf') as pdf:
    first_page = pdf.pages[0]
    print(first_page.extract_text())
